# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import pairwise_distances
from src.config import valuation_input_path

# %%
df = pd.read_csv("outputs/matched_pairs.csv")

# %%
test = pd.concat([df.filter(regex="^t_").rename(columns=lambda x: x[2:]), df.filter(regex="^c_").rename(columns=lambda x: x[2:])], axis=1)

# %%
test.columns[10:30]
# Out:
# Index(['target_market_value', 'acquiror_market_value', 'relative_market_value',
#        'target_roe', 'target_book_value_per_share',
#        'target_price_to_book_value', 'target_long_term_debt_to_cap',
#        'target_full_name', 'target_total_assets', 'target_debt_ratio',
#        'acquiror_book_value_per_share', 'acquiror_price_to_book_value',
#        'acquiror_roe', 'acquiror_debt_ratio', 'relative_total_assets',
#        'cross_nation', 'cross_industry', 'number_of_bidders',
#        'number_esg_raters', 'attitude'],
#       dtype='str')

# %%
test["target_industry"]
# Out:
#        target_industry                 target_industry
# 0   Telecommunications                     Industrials
# 1   Telecommunications                Consumer Staples
# 2          Industrials                Energy and Power
# 3          Industrials                     Industrials
# 4            Materials                      Healthcare
# 5     Energy and Power                 High Technology
# 6     Energy and Power                      Healthcare
# 7      High Technology  Consumer Products and Services
# 8          Industrials                Energy and Power
# 9     Energy and Power                     Industrials
# 10           Materials                Energy and Power
# 11     High Technology  Consumer Products and Services
# 12         Industrials                     Industrials
# 13         Industrials                     Industrials
# 14         Industrials                     Industrials
# 15         Industrials                     Industrials
# ...
